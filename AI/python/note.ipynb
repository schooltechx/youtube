# %% [markdown]
# ```
# python --version
# python -m venv env
# env/Scripts/activat
# pip list
# pip install package_name
# pip freeze > requirement.txt
# pip install -r requirement.txt
#
# ```
# Dataset
# Classification
# KNN = K Nearlest Neighbor

# %% [markdown]
# ขั้นตอน
#
# 2.
# 3.
# 4.
# 5.
# 6.
# ึ7. export model เป็นไฟล์ใช้ [joblib](https://joblib.readthedocs.io/en/stable/)
# !pip install joblib
# 8. load model เพื่อใช้งาน
#
#
#
# streamlit.io
